# %% [markdown]
# # Survival output test
# Testare il predict dei modelli, vorrei avere una predizione a piu' tempi sensata per i modelli che la supportano. Sarebbe carino anche sapere che tipo di output e', perche' per esempio antolini dovrebbe prendere una survival, altre metriche magari hanno bisogno di altro?
#
# Magari si puo' mettere altri metodi, tipo predict_survival, predict_failure, predict_hazard e predict_density per i metodi che lo supportano, con il predict normale che resta generico. Per farlo bisognerebbe esaminare ad uno ad uno i vari metodi

# %%
import numpy
import pandas
import sklearn

# %%
import survhive

# %%
X, y = survhive.load_test_data()
X.shape, y.shape
# Out:
# ((198, 84), (198,))

# %%
etimes = numpy.sort(survhive.get_time(y)[survhive.get_indicator(y)])
etimes
# Out:
# array([ 125.,  269.,  289.,  394.,  404.,  421.,  434.,  524.,  528.,
#         530.,  649.,  690.,  723.,  730.,  794.,  796.,  803.,  805.,
#         880.,  910.,  994., 1023., 1112., 1136., 1171., 1206., 1233.,
#        1259., 1598., 1693., 1721., 1731., 1742., 1743., 1815., 2349.,
#        2454., 2604., 2863., 3121., 3313., 3822., 3976., 4050., 4066.,
#        4212., 4353., 4415., 4618., 6777., 7185.])

# %%
ltime = numpy.linspace(0, etimes.max() * 1.1, num=100)

# %%
def plot_output(method, X, time):
    pred = method(X, time)
    #print(pred.shape, X.shape, time.shape)
    pred = pandas.DataFrame(
        pred, 
        index=X.index if hasattr(X, 'index') else [f'Ind{i}' for i, _ in enumerate(X)],
        columns=pandas.Index(time, name='time'),
    )

    pred.T.plot()

# %%
# uses global data!
def test_model(m):
    # times must be sorted (monotonicity check)
    assert m.predict(X).shape == (len(X),)

    surv = m.predict_survival(X, etimes[0])
    assert surv.shape == (len(X),)

    surv = m.predict_survival(X, etimes)
    assert surv.shape == (len(X), len(etimes)), f'bad predicted survival probability shape {surv.shape}, expected {(len(X), len(etimes))}'
    assert surv.min() >= 0.0, f'found {(surv < 0).mean():.%} negative values in predicted survival probabilities'
    assert surv.max() <= 1.0, f'{(surv > 1).mean():.%} of predicted survival probabilities are greater than 1'
    assert numpy.diff(surv).max() <= 0.0, 'survival monotonicity failure'

    #fail = m.predict_failure(X, etimes)
    #err = 1.0 - surv - fail
    #assert (numpy.abs(err) < 0.0000001).all()

# %% [markdown]
# ## CoxNet

# %%
coxnet = survhive.CoxNet(rng_seed=2309)
coxnet.fit(X, y)
# Out:
# CoxNet(rng_seed=2309, alpha=None, l1_ratio=0.5)

# %%
test_model(coxnet)

# %%
plot_output(coxnet.predict_survival, X[:10], etimes)

# %%
#plot_output(coxnet.model_.predict_cumulative_hazard_function, X[:10], etimes)

# %% [markdown]
# ## DeepHit

# %% [markdown]
# Fixme model should run without arguments, gives an error about the seed

# %%
try:
    deephit = survhive.DeepHitSingle()
    deephit.fit(X, y)
except ValueError as e:
    print(e)
    print('model should work without parameters!')
# Out:
# Seed must be between 0 and 2**32 - 1
# model should work without parameters!

# %%
deephit = survhive.DeepHitSingle(rng_seed=0, epochs=1)
deephit.fit(X, y)
# Out:
# /data/gbirolo/survhive/.venv/lib/python3.8/site-packages/torchtuples/callbacks.py:607: UserWarning: This overload of add is deprecated:
# 	add(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add(Tensor other, *, Number alpha) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1485.)
#   p.data = p.data.add(-weight_decay * eta, p.data)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /data/gbirolo/survhive/gb_test_survival_output.ipynb Cell 17 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2Bspoke8/data/gbirolo/survhive/gb_test_survival_output.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> deephit = survhive.DeepHitSingle(rng_seed=0, epochs=1)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bspoke8/data/gbirolo/survhive/gb_test_survival_output.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> deephit.fit(X, y)
#
# File ~/survhive/survhive/pycox_adapters.py:94, in DeepHitSingle.fit(self, X, y)
#      91 _callbacks = [tt.callbacks.EarlyStopping()]
#      92 # BIG FAT WARNING: fit returns a TrainingLogger, not a fitted model.
#      93 # there are side effects on model_ itself
# ---> 94 self.training_log_ = self.model_.fit(
#      95     X_train.astype("float32"),
#      96     y_train_discrete,
#      97     # num_workers=0 if True else n_jobs,
#      98     verbose=self.verbose,
#      99     batch_size=self.batch_size,
#     100     epochs=self.epochs,
#     101     callbacks=_callbacks,
#     102     val_data=(X_val.astype("float32"), y_val_discrete),
#     103 )
#     104 return self
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torchtuples/base.py:294, in Model.fit(self, input, target, batch_size, epochs, callbacks, verbose, num_workers, shuffle, metrics, val_data, val_batch_size, **kwargs)
#     290 if (is_dl(val_data) is False) and (val_data is not None):
#     291     val_dataloader = self.make_dataloader(
#     292         val_data, val_batch_size, shuffle=False, num_workers=num_workers, **kwargs
#     293     )
# --> 294 log = self.fit_dataloader(dataloader, epochs, callbacks, verbose, metrics, val_dataloader)
#     295 return log
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torchtuples/base.py:236, in Model.fit_dataloader(self, dataloader, epochs, callbacks, verbose, metrics, val_dataloader)
#     234     break
#     235 self.optimizer.zero_grad()
# --> 236 self.batch_metrics = self.compute_metrics(data, self.metrics)
#     237 self.batch_loss = self.batch_metrics["loss"]
#     238 self.batch_loss.backward()
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torchtuples/base.py:180, in Model.compute_metrics(self, data, metrics)
#     178 input = self._to_device(input)
#     179 target = self._to_device(target)
# --> 180 out = self.net(*input)
#     181 out = tuplefy(out)
#     182 return {name: metric(*out, *target) for name, metric in metrics.items()}
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torchtuples/practical.py:84, in MLPVanilla.forward(self, input)
#      83 def forward(self, input):
# ---> 84     return self.net(input)
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torchtuples/practical.py:61, in DenseVanillaBlock.forward(self, input)
#      59 input = self.activation(self.linear(input))
#      60 if self.batch_norm:
# ---> 61     input = self.batch_norm(input)
#      62 if self.dropout:
#      63     input = self.dropout(input)
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torch/nn/modules/batchnorm.py:171, in _BatchNorm.forward(self, input)
#     164     bn_training = (self.running_mean is None) and (self.running_var is None)
#     166 r"""
#     167 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     168 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     169 used for normalization (i.e. in eval mode when buffers are not None).
#     170 """
# --> 171 return F.batch_norm(
#     172     input,
#     173     # If buffers are not to be tracked, ensure that they won't be updated
#     174     self.running_mean
#     175     if not self.training or self.track_running_stats
#     176     else None,
#     177     self.running_var if not self.training or self.track_running_stats else None,
#     178     self.weight,
#     179     self.bias,
#     180     bn_training,
#     181     exponential_average_factor,
#     182     self.eps,
#     183 )
#
# File ~/survhive/.venv/lib/python3.8/site-packages/torch/nn/functional.py:2450, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2447 if training:
#    2448     _verify_batch_size(input.size())
# -> 2450 return torch.batch_norm(
#    2451     input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2452 )
#
# KeyboardInterrupt:

# %%
test_model(deephit)

# %%
#plot_output(deephit.predict_failure, X[:10], etimes)

# %%
plot_output(deephit.predict_survival, X[:10], etimes)

# %%
deephit.predict(X[:10])
# Out:
# array([0.33531053, 0.24560892, 0.21278814, 0.23046394, 0.40240325,
#        0.11844943, 0.3515696 , 0.07290528, 0.13838997, 0.19918797])

# %% [markdown]
# ## Auton

# %%
survmach = survhive.DeepSurvivalMachines(max_epochs=10)
survmach.fit(X, y)
# Out:
#  41%|████      | 4098/10000 [00:08<00:12, 477.26it/s]
# 100%|██████████| 10/10 [00:00<00:00, 23.67it/s]
# DeepSurvivalMachines(rng_seed=-1, n_distr=2, distr_kind='Weibull', batch_size=32, layer_sizes=[10, 10], learning_rate=0.001, validation_size=0.1, max_epochs=10, elbo=False)

# %%
test_model(survmach)

# %%
plot_output(survmach.model_.predict_pdf, X[:10], etimes.tolist())

# %%
plot_output(survmach.model_.predict_survival, X[:10], etimes.tolist())

# %%
plot_output(survmach.model_.predict_risk, X[:10], etimes.tolist())

# %% [markdown]
# # Metrics

# %% [markdown]
# ## Concordance index
# Ho esteso l'implementazione del c-index di sksurv per rishio dipendente dal tempo, non mi e' chiaro se otteniamo antolini o qualcosa diverso...
#
# Nello scorer uso la probabilita' cumulativa come rishio.

# %%
import sksurv
from survhive.util import get_indicator, get_time
from sklearn.metrics import make_scorer

# %%
from survhive.metrics import concordance_index_score
from survhive.metrics import concordance_index_td_scorer

# %%
# coxnet must return the same for both scores, since its prediction is time independent
s = make_scorer(concordance_index_score, return_all=True)
for m in [survmach, deephit, coxnet]:
    print(s(m, X, y))
s = lambda *args: concordance_index_td_scorer(*args, return_all=True)
for m in [survmach, deephit, coxnet]:
    print(s(m, X, y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /data/gbirolo/survhive/gb_test_survival_output.ipynb Cell 32 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bspoke8/data/gbirolo/survhive/gb_test_survival_output.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # coxnet must return the same for both scores, since its prediction is time independent
#       <a href='vscode-notebook-cell://ssh-remote%2Bspoke8/data/gbirolo/survhive/gb_test_survival_output.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> s = make_scorer(concordance_index_score, return_all=True)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bspoke8/data/gbirolo/survhive/gb_test_survival_output.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> for m in [survmach, deephit, coxnet]:
#       <a href='vscode-notebook-cell://ssh-remote%2Bspoke8/data/gbirolo/survhive/gb_test_survival_output.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     print(s(m, X, y))
#       <a href='vscode-notebook-cell://ssh-remote%2Bspoke8/data/gbirolo/survhive/gb_test_survival_output.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> s = lambda *args: concordance_index_td_scorer(*args, return_all=True)
#
# NameError: name 'survmach' is not defined

# %% [markdown]
# ## Brier

# %%
from survhive.metrics import brier_score
from survhive.metrics import make_time_dependent_scorer

# %%
# score for all event times
brier_score(y, 1 - coxnet.predict_survival(X, etimes), etimes)
# Out:
# 0.024205078833260275

# %%
# score for single time
brier_score(y, 1 - coxnet.predict_survival(X, etimes[20]), etimes[20])
# Out:
# 0.013785050849957094

# %%
# sksurv version of brier, this one accounts for censoring probabilities so it is slightly different from my implementation of the naive brier_score
sksurv.metrics.brier_score(y, y, coxnet.predict_survival(X, etimes[20]), etimes[20])
# Out:
# (array([994.]), array([0.01375474]))

# %%
s = make_time_dependent_scorer(brier_score)
for m in [survmach, deephit, coxnet]:
    print(s(m, X, y))
# Out:
# 0.11244037251249059
# 0.11224468327135928
# 0.024205078833260275

# %% [markdown]
# ## AUC

# %%
from survhive.metrics import make_time_dependent_classification_score
roc_auc_td_score = make_time_dependent_classification_score(sklearn.metrics.roc_auc_score)

roc_auc_td_score(y, 1 - coxnet.predict_survival(X, etimes[20]), etimes[20]), roc_auc_td_score(y, 1 - coxnet.predict_survival(X, etimes), etimes)
# Out:
# (0.9932359307359307, 0.9763924588024727)

# %%
s = make_time_dependent_scorer(roc_auc_td_score)
for m in [survmach, deephit, coxnet]:
    print(s(m, X, y))
# Out:
# 0.5887875965186244
# 0.5962738946191001
# 0.9763924588024728

# %%
s = make_time_dependent_scorer(roc_auc_td_score, time_mode='absolute', time_values=numpy.quantile(etimes, [0.25, 0.5, 0.75]))
for m in [survmach, deephit, coxnet]:
    print(s(m, X, y))

s = make_time_dependent_scorer(roc_auc_td_score, time_mode='quantiles', time_values=[0.25, 0.5, 0.75])
for m in [survmach, deephit, coxnet]:
    print(s(m, X, y))
# Out:
# 0.6222755435455521
# 0.6036499322284185
# 0.9757171890694057
# 0.6222755435455521
# 0.6036499322284185
# 0.9757171890694057

# %% [markdown]
# # Grid search tests
# Run optimize with more than one score

# %%
scoring = {
    'c-index-td': concordance_index_td_scorer,
    'brier': make_time_dependent_scorer(brier_score, time_mode='quantiles', time_values=[0.25, 0.5, 0.75]),
    'auc': make_time_dependent_scorer(roc_auc_td_score, time_mode='quantiles', time_values=[0.25, 0.5, 0.75]),
    #'c-index-median': make_time_dependent_scorer(concordance_index_score, time_mode='quantiles', time_values=[0.5]),
}

search_results = survhive.optimize(deephit, X, y, mode='sklearn-random', user_grid=dict(dropout=[0.0, 0.2, 0.9]), scoring=scoring, tries=3, refit='c-index-td')
# Out:
# Random search tries: 3

# %% [markdown]
# Qui vorrei tirare fuori i risultati, la funzione attuale va generalizzata

# %%
survhive.get_top_models(search_results[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /data/gbirolo/survhive/gb_test_survival_output.ipynb Cell 47 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bspoke8/data/gbirolo/survhive/gb_test_survival_output.ipynb#Y154sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> survhive.get_top_models(search_results[2])
#
# File ~/survhive/survhive/optimization.py:79, in get_top_models(search_results, top)
#      72 """evaluate the top best scoring result from an hyperparameter optimization.
#      73 Returns a tuple containing (rank, avg_cv_score, std_cv_score, params)
#      74 """
#      76 _cv_rez = search_results.cv_results_
#      77 return sorted(
#      78     zip(
# ---> 79         _cv_rez["rank_test_score"],
#      80         _cv_rez["mean_test_score"],
#      81         _cv_rez["std_test_score"],
#      82         _cv_rez["params"],
#      83     ),
#      84     key=lambda x: x[0],
#      85 )[:top]
#
# KeyError: 'rank_test_score'

# %%
search_results[2].cv_results_
# Out:
# {'mean_fit_time': array([1.07273393, 1.00663917, 2.0000396 ]),
#  'std_fit_time': array([0.15221689, 0.3912293 , 0.11072957]),
#  'mean_score_time': array([0.06165245, 0.06494212, 0.12148414]),
#  'std_score_time': array([0.01408874, 0.02702708, 0.0338403 ]),
#  'param_dropout': masked_array(data=[0.0, 0.2, 0.9],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'dropout': 0.0}, {'dropout': 0.2}, {'dropout': 0.9}],
#  'split0_test_c-index-td': array([0.58409786, 0.66666667, 0.64220183]),
#  'split1_test_c-index-td': array([0.43902439, 0.44947735, 0.40766551]),
#  'split2_test_c-index-td': array([0.66066066, 0.35735736, 0.36336336]),
#  'split3_test_c-index-td': array([0.36928105, 0.55228758, 0.62418301]),
#  'split4_test_c-index-td': array([0.5046729 , 0.65420561, 0.66043614]),
#  'split5_test_c-index-td': array([0.4408284 , 0.46449704, 0.46449704]),
#  'split6_test_c-index-td': array([0.56622517, 0.58940397, 0.56291391]),
#  'split7_test_c-index-td': array([0.63076923, 0.42769231, 0.33230769]),
#  'split8_test_c-index-td': array([0.76109215, 0.30716724, 0.39590444]),
#  'split9_test_c-index-td': array([0.54402516, 0.60691824, 0.62578616]),
#  'mean_test_c-index-td': array([0.5500677 , 0.50756734, 0.50792591]),
#  'std_test_c-index-td': array([0.11123796, 0.11820147, 0.12163344]),
#  'rank_test_c-index-td': array([1, 3, 2], dtype=int32),
#  'split0_test_brier': array([0.12883163, 0.33372595, 0.12009118]),
#  'split1_test_brier': array([0.12574148, 0.20527677, 0.12152789]),
#  'split2_test_brier': array([0.1045117 , 0.36113999, 0.12140101]),
#  'split3_test_brier': array([0.13161025, 0.1283508 , 0.14846695]),
#  'split4_test_brier': array([0.12542406, 0.10915448, 0.11396888]),
#  'split5_test_brier': array([0.28179441, 0.52123003, 0.1324517 ]),
#  'split6_test_brier': array([0.17680717, 0.12167873, 0.12955385]),
#  'split7_test_brier': array([0.10447411, 0.11837598, 0.16044594]),
#  'split8_test_brier': array([0.14987618, 0.1212135 , 0.1169707 ]),
#  'split9_test_brier': array([0.11281473, 0.14075993, 0.11902557]),
#  'mean_test_brier': array([0.14418857, 0.21609062, 0.12839037]),
#  'std_test_brier': array([0.05025331, 0.13430418, 0.01428071]),
#  'rank_test_brier': array([2, 1, 3], dtype=int32),
#  'split0_test_auc': array([0.69897103, 0.73710966, 0.58302665]),
#  'split1_test_auc': array([0.30115434, 0.52729367, 0.39499191]),
#  'split2_test_auc': array([0.84489865, 0.33995656, 0.27682218]),
#  'split3_test_auc': array([0.32062276, 0.49939875, 0.53795094]),
#  'split4_test_auc': array([0.40909975, 0.65105561, 0.6834079 ]),
#  'split5_test_auc': array([0.37296171, 0.44493994, 0.38070758]),
#  'split6_test_auc': array([0.62775781, 0.59951479, 0.56607997]),
#  'split7_test_auc': array([0.74043204, 0.28233432, 0.40968877]),
#  'split8_test_auc': array([0.77660734, 0.45424082, 0.55607664]),
#  'split9_test_auc': array([0.53103149, 0.5854251 , 0.60521968]),
#  'mean_test_auc': array([0.56235369, 0.51212692, 0.49939722]),
#  'std_test_auc': array([0.19167324, 0.13176945, 0.11990525]),
#  'rank_test_auc': array([1, 2, 3], dtype=int32)}

# %% [markdown]
# ## Antolini
# Tentativo di recuperare antolini da pycox, non cosi' semplice

# %%
import pycox
def antolini_scorer(estimator, X, y):
    surv = estimator.predict_survival(X, get_time(y))
    return pycox.evaluation.concordance.concordance_td(
        durations=get_time(y), events=get_indicator(y),
        surv=surv, surv_idx=numpy.arange(len(X)),
    )

for m in [survmach, deephit, coxnet]:
    #survmach.predict_survival(X[:10], etimes[0])
    s = antolini_scorer(m, X, y)
    print(s)
# Out:
# 0.0
# 0.0
# 0.009279131422800152

# %%
surv = deephit.model_.interpolate(10).predict_surv_df(X.astype('float32'))
surv
# Out:
#          0         1         2         3         4         5         6    \
# 0   0.982040  0.983530  0.957273  0.961069  0.979637  0.978322  0.951230
# 1   0.954923  0.939694  0.951613  0.936892  0.926224  0.939465  0.941091
# 2   0.927806  0.895858  0.945952  0.912716  0.872812  0.900607  0.930951
# 3   0.900689  0.852021  0.940292  0.888539  0.819399  0.861750  0.920811
# 4   0.873571  0.808185  0.934632  0.864362  0.765987  0.822892  0.910672
# ..       ...       ...       ...       ...       ...       ...       ...
# 86  0.013474  0.025237  0.017414  0.027800  0.018042  0.009669  0.021033
# 87  0.013078  0.024221  0.016893  0.026794  0.017783  0.009554  0.020417
# 88  0.012683  0.023206  0.016372  0.025788  0.017523  0.009440  0.019801
# 89  0.012287  0.022191  0.015851  0.024783  0.017264  0.009325  0.019185
# 90  0.011891  0.021176  0.015330  0.023777  0.017004  0.009210  0.018569
#
#          7         8         9    ...       188       189       190       191  \
# 0   0.951921  0.971899  0.900520  ...  0.978619  0.983513  0.971989  0.958093
# 1   0.928486  0.945268  0.894580  ...  0.946706  0.982410  0.951414  0.927698
# 2   0.905051  0.918637  0.888641  ...  0.914793  0.981307  0.930840  0.897303
# 3   0.881616  0.892006  0.882701  ...  0.882880  0.980204  0.910265  0.866908
# 4   0.858181  0.865375  0.876761  ...  0.850966  0.979101  0.889690  0.836513
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 86  0.012305  0.077866  0.032538  ...  0.018395  0.010547  0.021853  0.015868
# 87  0.012081  0.075834  0.031026  ...  0.017806  0.009856  0.020884  0.015585
# 88  0.011857  0.073803  0.029514  ...  0.017218  0.009164  0.019916  0.015302
# 89  0.011633  0.071771  0.028002  ...  0.016629  0.008473  0.018948  0.015020
# 90  0.011409  0.069739  0.026489  ...  0.016041  0.007781  0.017980  0.014737
#
#          192       193       194       195       196       197
# 0   0.956535  0.964016  0.983137  0.955347  0.928278  0.972919
# 1   0.945090  0.950885  0.956771  0.946290  0.915543  0.970473
# 2   0.933645  0.937754  0.930404  0.937234  0.902808  0.968026
# 3   0.922201  0.924623  0.904037  0.928177  0.890073  0.965580
# 4   0.910756  0.911492  0.877671  0.919120  0.877338  0.963133
# ..       ...       ...       ...       ...       ...       ...
# 86  0.030582  0.025705  0.031488  0.025032  0.023898  0.012120
# 87  0.029428  0.024119  0.030003  0.024107  0.023382  0.011449
# 88  0.028274  0.022534  0.028518  0.023182  0.022866  0.010778
# 89  0.027120  0.020948  0.027033  0.022256  0.022350  0.010107
# 90  0.025966  0.019363  0.025548  0.021331  0.021834  0.009437
#
# [91 rows x 198 columns]

# %%
surv = deephit.predict_survival(X, get_time(y))
# samples x times
surv.shape
# Out:
# (198, 198)

# %%
for m in [survmach, deephit, coxnet]:
    s = make_scorer(concordance_index_score)(m, X, y)
    print(s)
# Out:
# 0.5678575937381644
# 0.5427345032192905
# 0.9462189117535664

# %%
pycox.evaluation.EvalSurv(surv, get_time(y), get_indicator(y), censor_surv='km')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2456668/951264493.py in ?()
# ----> 1 pycox.evaluation.EvalSurv(surv, get_time(y), get_indicator(y), censor_surv='km')
#
# ~/survhive/.venv/lib/python3.8/site-packages/pycox/evaluation/eval_surv.py in ?(self, surv, durations, events, censor_surv, censor_durations, steps)
#      29         assert (type(durations) == type(events) == np.ndarray), 'Need `durations` and `events` to be arrays'
#      30         self.surv = surv
#      31         self.durations = durations
#      32         self.events = events
# ---> 33         self.censor_surv = censor_surv
#      34         self.censor_durations = censor_durations
#      35         self.steps = steps
#      36         assert pd.Series(self.index_surv).is_monotonic
#
# ~/survhive/.venv/lib/python3.8/site-packages/pycox/evaluation/eval_surv.py in ?(self, censor_surv)
#      47         if isinstance(censor_surv, EvalSurv):
#      48             self._censor_surv = censor_surv
#      49         elif type(censor_surv) is str:
#      50             if censor_surv == 'km':
# ---> 51                 self.add_km_censor()
#      52             else:
#      53                 raise ValueError(f"censor_surv cannot be {censor_surv}. Use e.g. 'km'")
#      54         elif censor_surv is not None:
#
# ~/survhive/.venv/lib/python3.8/site-packages/pycox/evaluation/eval_surv.py in ?(self, steps)
#     103         """
#     104         km = utils.kaplan_meier(self.durations, 1-self.events)
#     105         surv = pd.DataFrame(np.repeat(km.values.reshape(-1, 1), len(self.durations), axis=1),
#     106                             index=km.index)
# --> 107         return self.add_censor_est(surv, steps)
#
# ~/survhive/.venv/lib/python3.8/site-packages/pycox/evaluation/eval_surv.py in ?(self, censor_surv, steps)
#      91         round {str} -- For durations between values of `surv.index` choose the higher index 'pre'
#      92             or lower index 'post'. If `None` use `self.steps` (default: {None})
#      93         """
#      94         if not isinstance(censor_surv, EvalSurv):
# ---> 95             censor_surv = self._constructor(censor_surv, self.durations, 1-self.events, None,
#      96                                             steps=steps)
#      97         self.censor_surv = censor_surv
#      98         return self
#
# ~/survhive/.venv/lib/python3.8/site-packages/pycox/evaluation/eval_surv.py in ?(self, surv, durations, events, censor_surv, censor_durations, steps)
#      32         self.events = events
#      33         self.censor_surv = censor_surv
#      34         self.censor_durations = censor_durations
#      35         self.steps = steps
# ---> 36         assert pd.Series(self.index_surv).is_monotonic
#
# ~/survhive/.venv/lib/python3.8/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'is_monotonic'

# %%
pandas.__version__
# Out:
# '2.0.3'
