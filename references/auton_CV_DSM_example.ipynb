# %% [markdown]
# # `auton-survival` Cross Validation Survival Regression
#
# `auton-survival` offers a simple to use API to train Survival Regression Models that performs cross validation model selection by minimizing integrated brier score. In this notebook we demonstrate the use of `auton-survival` to train survival models on the *SUPPORT* dataset in cross validation fashion.

# %%
#import sys

#sys.path.append('../')
from auton_survival import datasets
outcomes, features = datasets.load_support()

# %%
from auton_survival.preprocessing import Preprocessor

cat_feats = ['sex', 'dzgroup', 'dzclass', 'income', 'race', 'ca']
num_feats = ['age', 'num.co', 'meanbp', 'wblc', 'hrt', 'resp', 
             'temp', 'pafi', 'alb', 'bili', 'crea', 'sod', 'ph', 
             'glucose', 'bun', 'urine', 'adlp', 'adls']

# Data should be processed in a fold-independent manner when performing cross-validation. 
# For simplicity in this demo, we process the dataset in a non-independent manner.
preprocessor = Preprocessor(cat_feat_strat='ignore', num_feat_strat= 'mean') 
x = preprocessor.fit_transform(features, cat_feats=cat_feats, num_feats=num_feats,
                                one_hot=True, fill_value=-1)

# %%
x
# Out:
#            age    num.co    meanbp          wblc       hrt      resp  \
# 0     0.012772 -1.390013  0.449837 -6.931821e-01 -0.892283 -0.138967
# 1    -0.148262  0.097711 -1.500702  5.187096e-01  0.470382  1.114591
# 2    -0.635153  0.097711 -0.525432 -4.201759e-01 -0.290175  0.487812
# 3    -1.299688  0.097711 -0.344827 -3.546971e-01 -0.290175  0.905665
# 4     1.105258 -0.646151 -0.922764  1.258366e-01  0.470382 -0.347893
# ...        ...       ...       ...           ...       ...       ...
# 9100  0.219471 -0.646151  0.883291 -5.403626e-01  0.216863 -0.138967
# 9101 -0.480786 -0.646151 -1.500702  1.939826e-16 -3.078884 -1.601451
# 9102  0.495813 -0.646151  0.955533 -4.312668e-01 -0.448624  0.069960
# 9103 -1.002436 -0.646151  0.522080 -5.185008e-01  0.407002  0.069960
# 9104  1.211332 -0.646151 -0.344827 -4.092983e-01 -0.892283  0.069960
#
#           temp          pafi           alb          bili  ...  dzclass_Coma  \
# 0    -0.881504  1.569019e+00 -1.655686e+00 -5.238337e-01  ...         False
# 1    -2.005013 -1.495658e+00 -6.389701e-16  9.880260e-17  ...         False
# 2     0.235766 -8.319880e-02 -6.389701e-16 -7.892740e-02  ...         False
# 3    -1.680444 -3.003564e-16 -6.389701e-16  9.880260e-17  ...         False
# 4     0.635237 -6.997670e-01 -6.389701e-16  9.880260e-17  ...         False
# ...        ...           ...           ...           ...  ...           ...
# 9100 -1.124933  4.276908e-01  1.077955e+00 -4.793410e-01  ...         False
# 9101  1.190748 -2.222321e-01 -6.389701e-16  9.880260e-17  ...          True
# 9102 -0.325992 -6.290945e-01 -6.389701e-16 -4.793410e-01  ...         False
# 9103 -0.563174  1.997678e+00 -2.518775e+00 -4.793410e-01  ...         False
# 9104 -0.725463 -9.640862e-02  2.229443e+00 -4.348415e-01  ...         False
#
#       income_$25-$50k  income_>$50k  income_under $11k  race_black  \
# 0               False         False              False       False
# 1               False         False              False       False
# 2               False         False               True       False
# 3               False         False               True       False
# 4               False         False              False       False
# ...               ...           ...                ...         ...
# 9100            False         False              False       False
# 9101            False         False              False       False
# 9102            False         False              False       False
# 9103            False         False              False       False
# 9104            False         False              False       False
#
#       race_hispanic  race_other  race_white  ca_no  ca_yes
# 0             False        True       False  False   False
# 1             False       False        True   True   False
# 2             False       False        True   True   False
# 3             False       False        True  False   False
# 4             False       False        True   True   False
# ...             ...         ...         ...    ...     ...
# 9100          False       False        True   True   False
# 9101          False       False        True   True   False
# 9102          False       False        True   True   False
# 9103          False       False        True  False    True
# 9104          False       False        True   True   False
#
# [9105 rows x 38 columns]

# %%
import numpy as np
times = np.quantile(outcomes.time[outcomes.event==1], [0.25, 0.5, 0.75]).tolist()

# %%
from auton_survival.experiments import SurvivalRegressionCV

param_grid = {'k' : [3],
              'distribution' : ['Weibull'],
              'learning_rate' : [1e-4, 1e-3],
              'layers' : [[100]]}

experiment = SurvivalRegressionCV(model='dsm', num_folds=3, hyperparam_grid=param_grid, random_seed=0)
model = experiment.fit(x, outcomes, times, metric='brs')
# Out:
# At hyper-param {'distribution': 'Weibull', 'k': 3, 'layers': [100], 'learning_rate': 0.0001}
# At fold: 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       3 param_grid = {'k' : [3],
#       4               'distribution' : ['Weibull'],
#       5               'learning_rate' : [1e-4, 1e-3],
#       6               'layers' : [[100]]}
#       8 experiment = SurvivalRegressionCV(model='dsm', num_folds=3, hyperparam_grid=param_grid, random_seed=0)
# ----> 9 model = experiment.fit(x, outcomes, times, metric='brs')
#
# File /usr/local/ivan/Unito/conda/envs/tosa-auton/lib/python3.10/site-packages/auton_survival/experiments.py:163, in SurvivalRegressionCV.fit(self, features, outcomes, horizons, metric)
#     161 print("At fold:", fold)
#     162 model = SurvivalModel(self.model, random_seed=self.random_seed, **hyper_param)
# --> 163 model.fit(features.loc[self.folds!=fold], outcomes.loc[self.folds!=fold])
#     164 predictions = model.predict_survival(features.loc[self.folds==fold], times=horizons)
#     166 score = survival_regression_metric(metric=self.metric,
#     167                                    outcomes=outcomes.loc[self.folds==fold],
#     168                                    predictions=predictions,
#     169                                    times=horizons,
#     170                                    outcomes_train=outcomes.loc[self.folds!=fold])
#
# File /usr/local/ivan/Unito/conda/envs/tosa-auton/lib/python3.10/site-packages/auton_survival/estimators.py:655, in SurvivalModel.fit(self, features, outcomes, vsize, val_data, weights, weights_val, resample_size)
#     651   self._model = _fit_rsf(features, outcomes,
#     652                          val_data, self.random_seed,
#     653                          **self.hyperparams)
#     654 elif self.model == 'dsm':
# --> 655   self._model = _fit_dsm(features, outcomes,
#     656                          val_data,
#     657                          self.random_seed,
#     658                          **self.hyperparams)
#     659 elif self.model == 'dcph':
#     660   self._model = _fit_dcph(features, outcomes,
#     661                           val_data,
#     662                           self.random_seed,
#     663                           **self.hyperparams)
#
# File /usr/local/ivan/Unito/conda/envs/tosa-auton/lib/python3.10/site-packages/auton_survival/estimators.py:395, in _fit_dsm(features, outcomes, val_data, random_seed, **hyperparams)
#     388 bs = hyperparams.get("batch_size", 128)
#     390 model = DeepSurvivalMachines(k=k, layers=layers,
#     391                              distribution=distribution,
#     392                              temp=temperature,
#     393                              random_seed=random_seed)
# --> 395 model.fit(x=features, t=outcomes.time, e=outcomes.event, val_data=val_data,
#     396           iters=epochs, learning_rate=lr, batch_size=bs)
#     398 return model
#
# File /usr/local/ivan/Unito/conda/envs/tosa-auton/lib/python3.10/site-packages/auton_survival/models/dsm/__init__.py:246, in DSMBase.fit(self, x, t, e, vsize, val_data, iters, learning_rate, batch_size, elbo, optimizer)
#     211 def fit(self, x, t, e, vsize=0.15, val_data=None,
#     212         iters=1, learning_rate=1e-3, batch_size=100,
#     213         elbo=True, optimizer="Adam"):
#     215   r"""This method is used to train an instance of the DSM model.
#     216
#     217   Parameters
#    (...)
#     243
#     244   """
# --> 246   processed_data = self._preprocess_training_data(x, t, e,
#     247                                                   vsize, val_data,
#     248                                                   self.random_seed)
#     249   x_train, t_train, e_train, x_val, t_val, e_val = processed_data
#     251   #Todo: Change this somehow. The base design shouldn't depend on child
#
# File /usr/local/ivan/Unito/conda/envs/tosa-auton/lib/python3.10/site-packages/auton_survival/models/dsm/__init__.py:324, in DSMBase._preprocess_training_data(self, x, t, e, vsize, val_data, random_seed)
#     321 np.random.shuffle(idx)
#     322 x_train, t_train, e_train = x[idx], t[idx], e[idx]
# --> 324 x_train = torch.from_numpy(x_train).double()
#     325 t_train = torch.from_numpy(t_train).double()
#     326 e_train = torch.from_numpy(e_train).double()
#
# TypeError: can't convert np.ndarray of type numpy.object_. The only supported types are: float64, float32, float16, complex64, complex128, int64, int32, int16, int8, uint8, and bool.

# %%
print(experiment.folds)
model
# Out:
# [2 2 0 ... 0 0 0]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 print(experiment.folds)
# ----> 2 model
#
# NameError: name 'model' is not defined

# %%
out_risk = model.predict_risk(x, times)
out_survival = model.predict_survival(x, times)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 out_risk = model.predict_risk(x, times)
#       2 out_survival = model.predict_survival(x, times)
#
# NameError: name 'model' is not defined

# %%
from auton_survival.metrics import survival_regression_metric

for fold in set(experiment.folds):
    print(survival_regression_metric('brs', outcomes[experiment.folds==fold], 
                                     out_survival[experiment.folds==fold], 
                                     times=times))

# %%
from auton_survival.metrics import survival_regression_metric

for fold in set(experiment.folds):
    print(survival_regression_metric('ctd', outcomes[experiment.folds==fold], 
                                     out_survival[experiment.folds==fold], 
                                     times=times))

# %%
for fold in set(experiment.folds):
    for time in times:
        print(time)
